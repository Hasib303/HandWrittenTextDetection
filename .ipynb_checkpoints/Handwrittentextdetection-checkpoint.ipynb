# %%
import tensorflow as tf
print(tf.__version__)
print(tf.keras.__file__)
# Out:
# 2.19.0
# /opt/anaconda3/lib/python3.12/site-packages/keras/api/_tf_keras/keras/__init__.py

# %%
conda install tensorflow
# Out:
# Retrieving notices: done
# Channels:
#  - defaults
#  - conda-forge
#  - pytorch
# Platform: osx-arm64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - tensorflow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2025.4.26          |  py312hca03da5_0         158 KB
#     ------------------------------------------------------------
#                                            Total:         158 KB
#
# The following packages will be UPDATED:
#
#   certifi            conda-forge/noarch::certifi-2025.1.31~ --> pkgs/main/osx-arm64::certifi-2025.4.26-py312hca03da5_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   conda              conda-forge::conda-24.11.3-py312h81bd~ --> pkgs/main::conda-24.11.3-py312hca03da5_0
#
#
#
# ...
#
# Preparing transaction: done
# ...

# %%
import tensorflow as tf

# %%
from keras.layers import StringLookup

# %%
# from tensorflow.keras.layers import StringLookup
from tensorflow import keras
import matplotlib.pyplot as plt
import tensorflow as tf

import numpy as np
import os

np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# # Data Splitting

# %%
base_path = "/Users/hasib/Code/HandWrittenTextDetection/Iam_handwriting_word_database"
words_list = []

words = open(f"{base_path}/words.txt", "r").readlines()
for line in words:
  if line[0] =="#":
    continue
  if line.split(" ")[1] != "err":
    words_list.append(line)

len(words_list)

np.random.shuffle(words_list)

# %%
print(words_list[0:10])
# Out:
# ['a03-059-08-06 ok 175 1956 2142 371 125 NP Atlantic\n', 'e04-022-00-03 ok 173 1023 727 272 147 JJ required\n', 'b05-055-00-00 ok 186 380 732 59 53 ATI The\n', 'a05-048-04-04 ok 173 1390 1543 170 44 MD may\n', 'd04-121-02-10 ok 180 2085 1119 73 22 NNS- re-\n', 'e04-095-06-06 ok 169 1412 1807 191 64 NN bottom\n', 'c04-110-01-06 ok 167 1038 958 19 46 ( (\n', 'e01-035-02-07 ok 181 1823 1080 182 58 NN-- lace-\n', 'e01-092-05-03 ok 178 1198 1622 72 78 INO of\n', 'c03-016d-03-06 ok 165 1736 1318 66 50 IN In\n']

# %%
# Dataset will be split into 3 subsets with 90:5:5 ratio
split_idx = int(0.9*len(words_list))
train_samples = words_list[:split_idx]
test_samples = words_list[split_idx:]

val_split_idx = int(0.5 * len(test_samples))
validation_samples = test_samples[:val_split_idx]
test_samples = test_samples[val_split_idx:]

assert len(words_list) == len(train_samples) + len(validation_samples) + len(test_samples)

print(f"Total Training Samples: {len(train_samples)}")
print(f"Total validation samples: {len(validation_samples)}")
print(f"Total test samples: {len(test_samples)}")
# Out:
# Total Training Samples: 34474
# Total validation samples: 1915
# Total test samples: 1916

# %% [markdown]
# # Data input pipline

# %%
print(base_image_path)
# Out:
# Iam_handwriting_word_database/words

# %%
base_image_path = os.path.join(base_path, "words")
print(base_path)
def get_image_paths_and_labels(samples):
    paths = []
    corrected_samples = []
    for (i, file_line) in enumerate(samples):
        line_split = file_line.strip()
        line_split = line_split.split(" ")

        # Each line split willl have this format for the the corresponding image:
        # part1/part1-part2/part1-part2-part3.png
        image_name = line_split[0]
        partI = image_name.split("-")[0]
        partII = image_name.split("-")[1]
        img_path = os.path.join(
             base_image_path, partI, partI + "-" + partII, image_name + ".png"
        )
        if os.path.getsize(img_path):
            paths.append(img_path)
            corrected_samples.append(file_line.split("\n")[0])

    return paths, corrected_samples

train_img_paths, train_labels = get_image_paths_and_labels(train_samples)
validation_img_paths, validation_labels = get_image_paths_and_labels(validation_samples)
test_img_paths, test_labels = get_image_paths_and_labels(test_samples)
# Out:
# /Users/hasib/Code/HandWrittenTextDetection/Iam_handwriting_word_database/words

# %%
import os

print(os.path.exists("Iam_handwriting_word_database/words/b04/b04-121/b04-121-04-04.png"))
# Out:
# False

# %%
import os
print(os.getcwd())
# Out:
# /Users/hasib/Code/HandWrittenTextDetection

# %%
base_path = "/Users/hasib/Code/HandWrittenTextDetection/Iam_handwriting_word_database"

# %%
img_path=os.path.abspath("/Users/hasib/Code/HandWrittenTextDetection/Iam_handwriting_word_database")
paths = []

# %%
def get_image_paths_and_labels(samples):
    paths = []
    corrected_samples = []
    missing_count = 0

    for (i, file_line) in enumerate(samples):
        line_split = file_line.strip().split(" ")
        image_name = line_split[0]
        partI = image_name.split("-")[0]
        partII = image_name.split("-")[1]
        
        img_path = os.path.join(
            base_image_path, partI, partI + "-" + partII, image_name + ".png"
        )

        if os.path.exists(img_path):
            paths.append(img_path)
            corrected_samples.append(file_line.strip())
        else:
            if missing_count < 20:
                print(f"Missing: {img_path}")
            missing_count += 1

    print(f"Total missing images: {missing_count}")
    return paths, corrected_samples

# %%
train_img_paths, train_labels = get_image_paths_and_labels(train_samples)
validation_img_paths, validation_labels = get_image_paths_and_labels(validation_samples)
test_img_paths, test_labels = get_image_paths_and_labels(test_samples)
# Out:
# Missing: /Users/hasib/Code/HandWrittenTextDetection/Iam_handwriting_word_database/words/a03/a03-059/a03-059-08-06.png
# Missing: /Users/hasib/Code/HandWrittenTextDetection/Iam_handwriting_word_database/words/e04/e04-022/e04-022-00-03.png
# Missing: /Users/hasib/Code/HandWrittenTextDetection/Iam_handwriting_word_database/words/b05/b05-055/b05-055-00-00.png
# Missing: /Users/hasib/Code/HandWrittenTextDetection/Iam_handwriting_word_database/words/a05/a05-048/a05-048-04-04.png
# Missing: /Users/hasib/Code/HandWrittenTextDetection/Iam_handwriting_word_database/words/d04/d04-121/d04-121-02-10.png
# Missing: /Users/hasib/Code/HandWrittenTextDetection/Iam_handwriting_word_database/words/e04/e04-095/e04-095-06-06.png
# Missing: /Users/hasib/Code/HandWrittenTextDetection/Iam_handwriting_word_database/words/c04/c04-110/c04-110-01-06.png
# Missing: /Users/hasib/Code/HandWrittenTextDetection/Iam_handwriting_word_database/words/e01/e01-035/e01-035-02-07.png
# ...

# %%
base_path = "/Users/hasib/Code/HandWrittenTextDetection/Iam_handwriting_word_database/words"
words_list = []

test_image_path = os.path.join(base_path, "words")
print(base_path)
print(test_image_path)


def get_image_paths_and_labels(samples):
    paths = []
    corrected_samples = []
    for (i, file_line) in enumerate(samples):
        line_split = file_line.strip()
        line_split = line_split.split(" ")

        # Each line split willl have this format for the the corresponding image:
        # part1/part1-part2/part1-part2-part3.png
        image_name = line_split[0]
        partI = image_name.split("-")[0]
        partII = image_name.split("-")[1]
        img_path = os.path.join(
             base_image_path, partI, partI + "-" + partII, image_name + ".png"
        )
        if os.path.getsize(img_path):
            paths.append(img_path)
            corrected_samples.append(file_line.split("\n")[0])

    return paths, corrected_samples

inf_img_paths, test_labels = get_image_paths_and_labels(test_samples)
# Out:
# /Users/hasib/Code/HandWrittenTextDetection/Iam_handwriting_word_database/words
# /Users/hasib/Code/HandWrittenTextDetection/Iam_handwriting_word_database/words/words

# %%
train_img_paths[0:10]
# Out:
# ['/Users/hasib/Code/HandWrittenTextDetection/Iam_handwriting_word_database/words/words/a03/a03-059/a03-059-08-06.png',
#  '/Users/hasib/Code/HandWrittenTextDetection/Iam_handwriting_word_database/words/words/e04/e04-022/e04-022-00-03.png',
#  '/Users/hasib/Code/HandWrittenTextDetection/Iam_handwriting_word_database/words/words/b05/b05-055/b05-055-00-00.png',
#  '/Users/hasib/Code/HandWrittenTextDetection/Iam_handwriting_word_database/words/words/a05/a05-048/a05-048-04-04.png',
#  '/Users/hasib/Code/HandWrittenTextDetection/Iam_handwriting_word_database/words/words/d04/d04-121/d04-121-02-10.png',
#  '/Users/hasib/Code/HandWrittenTextDetection/Iam_handwriting_word_database/words/words/e04/e04-095/e04-095-06-06.png',
#  '/Users/hasib/Code/HandWrittenTextDetection/Iam_handwriting_word_database/words/words/c04/c04-110/c04-110-01-06.png',
#  '/Users/hasib/Code/HandWrittenTextDetection/Iam_handwriting_word_database/words/words/e01/e01-035/e01-035-02-07.png',
# ...

# %%
train_labels[0: 10]
# Out:
# ['a03-059-08-06 ok 175 1956 2142 371 125 NP Atlantic',
#  'e04-022-00-03 ok 173 1023 727 272 147 JJ required',
#  'b05-055-00-00 ok 186 380 732 59 53 ATI The',
#  'a05-048-04-04 ok 173 1390 1543 170 44 MD may',
#  'd04-121-02-10 ok 180 2085 1119 73 22 NNS- re-',
#  'e04-095-06-06 ok 169 1412 1807 191 64 NN bottom',
#  'c04-110-01-06 ok 167 1038 958 19 46 ( (',
#  'e01-035-02-07 ok 181 1823 1080 182 58 NN-- lace-',
#  'e01-092-05-03 ok 178 1198 1622 72 78 INO of',
#  'c03-016d-03-06 ok 165 1736 1318 66 50 IN In']

# %%
# find maximum lengtrh and the size of the vocabulary in the training data.

train_labels_cleaned = []
characters = set()
max_len = 0

for label in train_labels:
  label = label.split(" ")[-1].strip()
  for char in label:
    characters.add(char)

  max_len = max(max_len, len(label))
  train_labels_cleaned.append(label)

print("Maximum length: ", max_len)
print("Vocab size: ", len(characters))

# Check some label samples
train_labels_cleaned[:10]
# Out:
# Maximum length:  19
# Vocab size:  76
# ['Atlantic',
#  'required',
#  'The',
#  'may',
#  're-',
#  'bottom',
#  '(',
#  'lace-',
#  'of',
#  'In']

# %%
def clean_labels(labels):
  cleaned_labels = []
  for label in labels:
    label = label.split(" ")[-1].strip()
    cleaned_labels.append(label)
  return cleaned_labels

validation_labels_cleaned = clean_labels(validation_labels)
test_labels_cleaned = clean_labels(test_labels)

# %%
ff = list(characters)

# %%
import pickle

# Save to pickle file
with open("/Users/hasib/Code/HandWrittenTextDetection/characters.pkl", "wb") as fp:
    pickle.dump(characters, fp)

# %%
import pickle

with open("/Users/hasib/Code/HandWrittenTextDetection/characters.pkl", "rb") as fp:  # Unpickling
    b = pickle.load(fp)
    print(b)
# Out:
# {'M', 'p', '#', 'b', 'f', 'L', 'e', 'y', '/', '?', 'i', 'J', 'v', 'g', 'P', 'c', 'B', 'A', ':', 'w', 'X', 't', 'x', 'o', 'K', 'Z', '.', '(', '8', '7', 'u', 'C', '4', 'd', 's', ',', 'm', '6', 'E', 'S', 'D', "'", 'n', 'U', ')', '2', '0', '*', 'r', 'q', ';', 'Q', 'F', 'k', 'h', '"', '1', '9', 'O', 'j', 'Y', '3', 'T', 'G', 'W', 'R', 'N', 'I', '5', 'z', 'H', 'a', '-', 'l', 'V', '!'}

# %%
#Building the chracter vocabulary
AUTOTUNE = tf.data.AUTOTUNE

# Maping characaters to integers
char_to_num = StringLookup(vocabulary=list(characters), mask_token=None)

#Maping integers back to original characters
num_to_chars = StringLookup(vocabulary=char_to_num.get_vocabulary(), mask_token=None, invert=True)

# %%
def distortion_free_resize(image, img_size):
  w, h = img_size
  image = tf.image.resize(image, size=(h, w), preserve_aspect_ratio=True)

  # Check tha amount of padding needed to be done.
  pad_height = h - tf.shape(image)[0]
  pad_width = w - tf.shape(image)[1]

  # only necessary if you want to do same amount of padding on both sides.
  if pad_height % 2 != 0:
    height = pad_height // 2
    pad_height_top = height +1
    pad_height_bottom = height
  else:
    pad_height_top = pad_height_bottom = pad_height // 2

  if pad_width % 2 != 0:
    width = pad_width // 2
    pad_width_left = width + 1
    pad_width_right = width
  else:
    pad_width_left = pad_width_right = pad_width // 2

  image = tf.pad(
      image, paddings=[
          [pad_height_top, pad_height_bottom],
          [pad_width_left, pad_width_right],
          [0, 0],
      ],
  )
  image = tf.transpose(image, perm=[1,0,2])
  image = tf.image.flip_left_right(image)
  return image

# %%
batch_size = 64
padding_token = 99
image_width = 128
image_height = 32

def preprocess_image(image_path, img_size=(image_width, image_height)):
  image = tf.io.read_file(image_path)
  image = tf.image.decode_png(image, 1)
  image = distortion_free_resize(image, img_size)
  image = tf.cast(image, tf.float32) / 255.0
  return image

def vectorize_label(label):
  label = char_to_num(tf.strings.unicode_split(label, input_encoding="UTF-8"))
  length = tf.shape(label)[0]
  pad_amount = max_len - length
  label = tf.pad(label, paddings=[[0, pad_amount]], constant_values=padding_token)
  return label

 

def process_images_labels(image_path, label):
  image = preprocess_image(image_path)
  label = vectorize_label(label)
  return {"image": image, "label": label}
  
def prepare_dataset(image_paths, labels):
  dataset = tf.data.Dataset.from_tensor_slices((image_paths, labels)).map(
    process_images_labels, num_parallel_calls=AUTOTUNE
  )

  return dataset.batch(batch_size).cache().prefetch(AUTOTUNE)

# %%
# Prepare tf.data.Dataset objects
train_ds = prepare_dataset(train_img_paths, train_labels_cleaned)
validation_ds = prepare_dataset(validation_img_paths, validation_labels_cleaned)
test_ds = prepare_dataset(test_img_paths, test_labels_cleaned)

# %%
# Visualize few samples

for data in train_ds.take(1):
  images, labels = data["image"], data["label"]
  _, ax = plt.subplots(4, 4, figsize=(15, 8))

  for i in range(16): 
    img = images[i]
    img = tf.image.flip_left_right(img)
    img = tf.transpose(img, perm=[1, 0, 2])
    img = (img * 255.0).numpy().clip(0, 255).astype(np.uint8)
    img = img[:, :, 0]

    # Gather indices where Label!= padding token
    label = labels[i]
    indices = tf.gather(label, tf.where(tf.math.not_equal(label, padding_token)))
    # Convert to string.
    label = tf.strings.reduce_join(num_to_chars(indices))
    label = label.numpy().decode("utf-8")

    ax[i // 4, i % 4].imshow(img, cmap="gray")
    ax[i // 4, i % 4].set_title(label)
    ax[i // 4, i % 4].axis("off")

  plt.show()
# Out:
# 2025-04-30 13:54:00.651239: W tensorflow/core/kernels/data/cache_dataset_ops.cc:916] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.
# 2025-04-30 13:54:01.067484: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# # Model

# %%
class CTCLayer(keras.layers.Layer):

  def __init__(self, name=None):
    super().__init__(name=name)
    self.loss_fn = keras.backend.ctc_batch_cost

  def call(self, y_true, y_pred):
    batch_len = tf.cast(tf.shape(y_true)[0], dtype="int64")
    input_length = tf.cast(tf.shape(y_pred)[1], dtype="int64")
    label_length = tf.cast(tf.shape(y_true)[1], dtype="int64")

    input_length = input_length * tf.ones(shape=(batch_len, 1), dtype="int64")
    label_length = label_length * tf.ones(shape=(batch_len, 1), dtype="int64")
    loss = self.loss_fn(y_true, y_pred, input_length, label_length)
    self.add_loss(loss)

    # At test time, just return the computed predictions.
    return y_pred

def build_model():
  input_img = keras.Input(shape=(image_width, image_height, 1), name="image")
  labels = keras.layers.Input(name="label", shape=(None,))

  # first conv block
  x = keras.layers.Conv2D(
      32, (3,3), activation = "relu",
      kernel_initializer="he_normal",
      padding="same",
      name="Conv1"
  )(input_img)
  x = keras.layers.MaxPooling2D((2,2), name="pool1")(x)

  # Second conv block
  x = keras.layers.Conv2D(
      64, (3,3), activation = "relu", kernel_initializer="he_normal",
      padding="same",
      name="Conv2"
  )(x)
  x = keras.layers.MaxPooling2D((2,2), name="pool2")(x)

  # We have two maxpool layers with pool size and strides 2
  # Hence downsampled feature maps are 4x smaller the number of filters in the last layer is 64, 
  # Reshape accordingly before passing the output to the RNN part of the model.
  
  new_shape = ((image_width // 4), (image_height // 4) * 64)
  x = keras.layers.Reshape(target_shape=new_shape, name="reshape")(x)
  x = keras.layers.Dense(64, activation="relu", name="dense1")(x)
  x = keras.layers.Dropout(0.2)(x)

  # RNN
  x = keras.layers.Bidirectional(
      keras.layers.LSTM(128, return_sequences=True, dropout=0.25)
  )(x)
  x = keras.layers.Bidirectional(
    keras.layers.LSTM(64, return_sequences=True, dropout=0.25)
  )(x)
  # +2 is to account for the two special tokens introduced by the CTC loss.
  # The recommendation comes here: https://git.10/J0eXP.
  x = keras.layers.Dense(
    len(char_to_num.get_vocabulary()) + 2, activation="softmax", name="dense2"
  )(x)
  # Add CTC layer for calculating CTC Loss at each step.
  output = CTCLayer(name="ctc_loss")(labels, x)

  # Define the model.
  model = keras.models.Model(
      inputs=[input_img, labels], outputs=output, name="handwriting_recognizer"
  )
  
  # optimizer
  opt = keras.optimizers.Adam()
  # Compile the model and return
  model.compile(optimizer=opt)
  return model

# Get the model
model = build_model()
model.summary()
# Out:
# Model: "handwriting_recognizer"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ image (InputLayer)  │ (None, 128, 32,   │          0 │ -                 │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 128, 32,   │        320 │ image[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1               │ (None, 64, 16,    │          0 │ Conv1[0][0]       │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %% [markdown]
# # Evaluation Metrix

# %%
validation_images = []
validation_labels = []

for batch in validation_ds:
  validation_images.append(batch["image"])
  validation_labels.append(batch["label"])
# Out:
# 2025-04-30 13:55:40.034721: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
def calculate_edit_distance(labels, predictions):
  # Get a single batch and convert its labels to sparse tensors.
  sparse_labels = tf.cast(tf.sparse.from_dense(labels), dtype=tf.int64)

  # Make predictions and convert them to sparse tensors.
  input_len = np.ones(predictions.shape[0]) * predictions.shape[1]
  predictions_decoded = keras.backend.ctc_decode(
    predictions, input_length=input_len, greedy=True
  )[0][0][:, :max_len]
  sparse_predictions = tf.cast(
    tf.sparse.from_dense(predictions_decoded), dtype=tf.int64
  )

  # Compute individual edit distances and average them out.
  edit_distances = tf.edit_distance(
    sparse_predictions, sparse_labels, normalize=False
  )
  return tf.reduce_mean(edit_distances)

class EditDistanceCallback(keras.callbacks.Callback):
  def __init__(self, pred_model):
    super().__init__()
    self.prediction_model = pred_model
  def on_epoch_end(self, epoch, logs = None):
    edit_distances = []

    for i in range(len(validation_images)):
      labels = validation_labels[i]
      predictions = self.prediction_model.predict(validation_images[i])
      edit_distances.append(calculate_edit_distance(labels, predictions).numpy())
    print(f"Mean eidt distance for each {epoch + 1}: {np.mean(edit_distances): .4f}")

# %% [markdown]
# # Training

# %%
model = build_model()

# Print model inputs to confirm names and structure
print("Model inputs:")
for i, inp in enumerate(model.inputs):
    print(f"Input {i}: {inp.name}, shape: {inp.shape}")

# Use model.get_layer(name="dense2") only if you're sure the layer exists
# Otherwise use model.layers[-1] to get the last layer if needed

# Extract just the image input (usually first input)
image_input = model.inputs[0]  # or use model.get_layer(name="image").input if named

# Build a prediction model from image input to dense2 output
prediction_model = keras.models.Model(
    inputs=image_input,
    outputs=model.get_layer(name="dense2").output
)

# Optional: define custom callback if needed (like EditDistanceCallback)
edit_distance_callback = EditDistanceCallback(prediction_model)

# Set number of epochs
epochs = 20  # Ideally at least 50 for better results

# Fit the model
history = model.fit(
    train_ds,
    validation_data=validation_ds,
    epochs=epochs,
    callbacks=[edit_distance_callback],
)
# Out:
# Model inputs:
# Input 0: image, shape: (None, 128, 32, 1)
# Input 1: label, shape: (None, None)
# Epoch 1/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step step - loss: 1280.73
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# ...

# %%
# A utility function to decode the output of the network
pred_test_text = []
def decode_batch_predictions(pred):
    input_len = np.ones(pred.shape[0]) * pred.shape[1]
    # Use greedy search. For complex tasks, you can use beam search.
    results = keras.backend.ctc_decode(pred, input_length=input_len, greedy=True)[0][0][
        :, :max_len
    ]

    # Iterate over the results and get back the text.
    output_text = []

    for res in results:
      res = tf.gather(res, tf.where(tf.math.not_equal(res, -1)))
      res = tf.strings.reduce_join(num_to_chars(res)).numpy().decode("utf-8")
      output_text.append(res)

    return output_text

# %%
# Let's check results on sone test samples.
for batch in test_ds.take(1):
    batch_images = batch["image"]

    _, ax = plt.subplots(4, 4, figsize=(15, 8))

    preds = prediction_model.predict(batch_images)
    pred_texts = decode_batch_predictions(preds)
    pred_test_text.append(pred_texts)

    for i in range(16):
      img = batch_images[i]
      img = tf.image.flip_left_right(img)
      img = tf.transpose(img, perm=[1, 0, 2])
      img = (img * 255.0).numpy().clip(0, 255).astype(np.uint8)
      img = img[:, :, 0]

      title = f"Prediction: {pred_texts[i]}"
      ax[i // 4, i % 4].imshow(img, cmap = "gray")
      ax[i // 4, i % 4].set_title(title)
      ax[i // 4, i % 4].axis("off")

    plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2025-04-30 22:29:35.690487: W tensorflow/core/kernels/data/cache_dataset_ops.cc:916] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %%
flat_list = [item for sublist in pred_test_text for item in sublist]
print(flat_list)
# Out:
# ['wseful', 'the', 'Righteen', 'future', 'the', 'But', 'scientific', 'into', 'deliberate', 'on', 'was', 'He', 'batlinson', 'is', 'tust', 'to', 'it-', 'ecacting', 'thiss', 'daye', 'offe', 'But', 'part-outhor', 'uy', 'mo', 'the', 'stunt', 'in', ')', 'thome', 'ani', 'dittorent', 'with', 'two', 'side', 'was', 'who', 'sitvation', '.', 'fut', ',', 'a', 'gparthiid', ',', 'to', 'the', 'paust', 'his', ',', 'of', 'Mr.', '1s', 'Lord', 'grect', 'that', 'lighil', 'fragmont', 'with', '.', 'goruty', ',', 'anling', 'the', 'for']

# %%
sentence = ' '.join(flat_list)
print(sentence)
# Out:
# wseful the Righteen future the But scientific into deliberate on was He batlinson is tust to it- ecacting thiss daye offe But part-outhor uy mo the stunt in ) thome ani dittorent with two side was who sitvation . fut , a gparthiid , to the paust his , of Mr. 1s Lord grect that lighil fragmont with . goruty , anling the for

# %%
# Save the whole model (architecture + weights + optimizer state)
model.save("character_model.keras")

# %%
from keras import backend as K
from keras.layers import Layer
from keras.saving import register_keras_serializable
import tensorflow as tf

@register_keras_serializable()
class CTCLayer(Layer):
    def __init__(self, name="ctc_loss", **kwargs):
        super().__init__(name=name, **kwargs)

    def call(self, inputs, **kwargs):
        y_true, y_pred = inputs

        # Infer batch size
        batch_size = tf.shape(y_pred)[0]
        input_length = tf.fill([batch_size, 1], tf.shape(y_pred)[1])
        label_length = tf.fill([batch_size, 1], tf.shape(y_true)[1])

        loss = tf.keras.backend.ctc_batch_cost(y_true, y_pred, input_length, label_length)
        self.add_loss(loss)

        return y_pred

    def compute_output_shape(self, input_shape):
        return input_shape[1]  # same shape as y_pred

    def get_config(self):
        base_config = super().get_config()
        return base_config

    @classmethod
    def from_config(cls, config):
        return cls(**config)

# %%
model.save("character_model.keras")
